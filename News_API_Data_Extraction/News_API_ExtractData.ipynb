# %%
#impotr required libraries
import requests
import re
import os
import pandas as pd

# %%
#API key
secret = os.environ(NEWS_API_KEY)
query1 = "recession"
query2 = "ai"
query3 = "technology"
query4 = "economics"

# %%
url = 'https://newsapi.org/v2/everything?'

# %% [markdown]
# ### Recession

# %%
#providing the query parameters
parameters = {
    'q': query1, # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'popularity'
}
# Call API using get method
response1 = requests.get(url, params=parameters)
# Convert the response to JSON format and pretty print it
response_json1 = response1.json()

# %% [markdown]
# ### AI

# %%
parameters = {
    'q': query2, # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'popularity'
}
# Call API using get method
response2 = requests.get(url, params=parameters)
# Convert the response to JSON format and pretty print it
response_json2 = response2.json()

# %% [markdown]
# ### Technology

# %%
parameters = {
    'q': query3, # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'popularity'
}
# Call API using get method
response3 = requests.get(url, params=parameters)
# Convert the response to JSON format and pretty print it
response_json3 = response3.json()

# %% [markdown]
# ### Economics

# %%
parameters = {
    'q': query4, # query phrase
    'pageSize': 100,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy':'popularity'
}
# Call API using get method
response4 = requests.get(url, params=parameters)
# Convert the response to JSON format and pretty print it
response_json4 = response4.json()

# %% [markdown]
# ## Extract articles by querying the urls and create a text file for each

# %% [markdown]
# ### Recession Articles

# %%
for i, article in enumerate(response_json1["articles"]):
      #print("Extracting Data from URL - %s"%article["url"])
      content_li = article["description"]
      #if there is any empty description, handle the exception
      if content_li is None:
        pass
      else:
        with open("/content/%s/%s_%d.txt"%(query1, query1, i), "w+", encoding="utf-8") as file_obj:
            file_obj.writelines(content_li)
        #print("Success")

# %% [markdown]
# ### AI Articles

# %%
for i, article in enumerate(response_json2["articles"]):
      #print("Extracting Data from URL - %s"%article["url"])
      content_li = article["description"]
      #if there is any empty description, handle the exception
      if content_li is None:
        pass
      else:
        with open("/content/%s/%s_%d.txt"%(query2, query2, i), "w+", encoding="utf-8") as file_obj:
            file_obj.writelines(content_li)
        #print("Success")

# %% [markdown]
# ### Technology Articles

# %%
for i, article in enumerate(response_json3["articles"]):
      #print("Extracting Data from URL - %s"%article["url"])
      content_li = article["description"]
      #if there is any empty description, handle the exception
      if content_li is None:
        pass
      else:
        with open("/content/%s/%s_%d.txt"%(query3, query3, i), "w+", encoding="utf-8") as file_obj:
            file_obj.writelines(content_li)
        #print("Success")

# %% [markdown]
# ### Economics Articles

# %%
for i, article in enumerate(response_json4["articles"]):
      #print("Extracting Data from URL - %s"%article["url"])
      content_li = article["description"]
      #if there is any empty description, handle the exception
      if content_li is None:
        pass
      else:
        with open("/content/%s/%s_%d.txt"%(query4, query4, i), "w+", encoding="utf-8") as file_obj:
            file_obj.writelines(content_li)
        #print("Success")

# %% [markdown]
# ## Add labels and description in list and create dataframe

# %% [markdown]
# ### Recession DataFrame

# %%
Description = []
recession = []
for ll in os.listdir("/content/recession/"):
    with open("/content/recession/%s"%ll, "r", encoding='ISO-8859-1') as file_obj:
        content = file_obj.read()
        Description.append(content)
        recession.append("recession")

# %%
rdf = pd.DataFrame(list(zip(recession, Description)), columns=["Label", "Description"])

# %%
rdf.head()
# Out:
#        Label                                        Description
# 0  recession  "The longer rates stay high, the more the Fed ...
# 1  recession  With the economy looming large in the 2024 ele...
# 2  recession  Itâs time for the president to adopt the les...
# 3  recession  Employee confidence has dropped to an 8-year-l...
# 4  recession  The decision comes days after GDP data rebuked...

# %% [markdown]
# ### AI DataFrame

# %%
Description = []
ai = []
for ll in os.listdir("/content/ai/"):
    with open("/content/ai/%s"%ll, "r", encoding='ISO-8859-1') as file_obj:
        content = file_obj.read()
        Description.append(content)
        ai.append("ai")

# %%
adf = pd.DataFrame(list(zip(ai, Description)), columns=["Label", "Description"])
adf.head()
# Out:
#   Label                                        Description
# 0    ai  Google must ensure that it canât use student...
# 1    ai  The Samsung Galaxy S24 isnât taking Googleâ...
# 2    ai  Microsoft\n and OpenAI\n say that several stat...
# 3    ai  Google is still mostly supported by ads but it...
# 4    ai  AI is elbowing its way into ever more jobs, bu...

# %% [markdown]
# ### Technology DataFrame

# %%
Description = []
technology = []
for ll in os.listdir("/content/technology/"):
    with open("/content/technology/%s"%ll, "r", encoding='ISO-8859-1') as file_obj:
        content = file_obj.read()
        Description.append(content)
        technology.append("technology")

# %%
tdf = pd.DataFrame(list(zip(technology, Description)), columns=["Label", "Description"])
tdf.head()
# Out:
#         Label                                        Description
# 0  technology  No wonder voters are unconvinced when politici...
# 1  technology  Iâve been using the AIAIAI Unit-4 Wireless+\...
# 2  technology  âIf molecules really were the new microchips...
# 3  technology  Amazonâs failure to buy iRobot leaves the ma...
# 4  technology  OpenAI is reportedly developing âagent softw...

# %% [markdown]
# ### Economics DataFrame

# %%
Description = []
economics = []
for ll in os.listdir("/content/economics/"):
    with open("/content/economics/%s"%ll, "r", encoding='ISO-8859-1') as file_obj:
        content = file_obj.read()
        Description.append(content)
        economics.append("economics")

# %%
edf = pd.DataFrame(list(zip(economics, Description)), columns=["Label", "Description"])
edf.head()
# Out:
#        Label                                        Description
# 0  economics  The blimp, the airship, the dirigible. Whateve...
# 1  economics  Back in 2004,  Stewart made an appearance on C...
# 2  economics  DC is supported by strong solar legislation. B...
# 3  economics  It's a mighty fine time to be a pro wrestling ...
# 4  economics  During the pandemic 20-somethings were asked t...

# %% [markdown]
# ## Merge all the dataframes

# %%
result = pd.concat([rdf, adf, tdf, edf], axis=0)

result.reset_index(drop = True, inplace = True)
result.to_csv("/content/FinalData.csv", index=False)

# %%
result.sample(frac=1).head(10)
# Out:
#           Label                                        Description
# 61    recession  Yardeni's cheery outlook comes with the econom...
# 390   economics  Donald Trump can't help bragging about his wea...
# 253  technology  Despite the flagging economy, demand is strong...
# 46    recession  "While there is a logic to the Fed's approach,...
# 359   economics  We can all be inconsistent. Philosophy illumin...
# 108          ai  Amazonâs failure to buy iRobot leaves the ma...
# 395   economics  Closing underperforming stores and shutting at...
# 44    recession  Centering U.S. foreign policy on this principl...
# 358   economics  Subfreezing conditions and treacherous roads h...
# 215  technology  Boseâs new earbuds have a clip-on design and...

# %%
########################################################################################################################################
